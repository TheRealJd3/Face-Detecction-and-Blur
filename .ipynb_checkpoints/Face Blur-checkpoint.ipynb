# %%
import face_detection_and_blur

# %%
face_detection_and_blur.run_fd()
import matplotlib.pyplot as plt
img = plt.imread('groupp1.jpg')
plt.title('Original')
plt.imshow(img, cmap='gray')
plt.show()
# Out:
# Face - 1
# Blurred Face - 1
# Face - 2
# Blurred Face - 2
# Face - 3
# Blurred Face - 3
# Face - 4
# Blurred Face - 4
